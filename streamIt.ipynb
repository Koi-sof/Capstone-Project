# %%
import streamlit as st
import joblib
import torch
import os

# Force CPU
os.environ['CUDA_VISIBLE_DEVICES'] = ''

# Load model
@st.cache_resource
def load_model():
    model = joblib.load('emotion_classifier.joblib')
    model.device = torch.device('cpu')
    if hasattr(model, 'model'):
        model.model = model.model.to('cpu')
    return model

model = load_model()

def predict_emotions(texts):
    predictions = model.predict(texts)
    return [[model.classes_[i] for i, pred in enumerate(row) if pred == 1] for row in predictions]

# App
st.title("Emotion Classifier")
user_input = st.text_area("Enter text to analyze:", height=100)

if st.button("Analyze Emotions"):
    if user_input.strip():
        emotions = predict_emotions([user_input])[0]
        if emotions:
            st.write("Detected emotions:", ", ".join(emotions))
        else:
            st.write("No emotions detected")
    else:
        st.write("Please enter some text")
# Out:
# 2025-11-04 12:56:02.215 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-04 12:56:02.283
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\User\anaconda3\envs\capstone\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-11-04 12:56:02.284 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-04 12:56:02.285 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-04 12:56:02.286 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-04 12:56:02.304 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-04 12:56:02.305 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-04 12:56:02.306 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 18
#      15         model.model = model.model.to('cpu')
#      16     return model
# ---> 18 model = load_model()
#      20 def predict_emotions(texts):
#      21     predictions = model.predict(texts)
#
# File ~\anaconda3\envs\capstone\Lib\site-packages\streamlit\runtime\caching\cache_utils.py:228, in CachedFunc.__call__(self, *args, **kwargs)
#     225     else:
#     226         spinner_message = f"Running `{name}(...)`."
# --> 228 return self._get_or_create_cached_value(args, kwargs, spinner_message)
#
# File ~\anaconda3\envs\capstone\Lib\site-packages\streamlit\runtime\caching\cache_utils.py:270, in CachedFunc._get_or_create_cached_value(self, func_args, func_kwargs, spinner_message)
#     264 spinner_or_no_context = (
#     265     spinner(spinner_message, _cache=True, show_time=self._info.show_time)
#     266     if spinner_message is not None and not is_nested_cache_function
#     267     else contextlib.nullcontext()
#     268 )
#     269 with spinner_or_no_context:
# --> 270     return self._handle_cache_miss(cache, value_key, func_args, func_kwargs)
#
# File ~\anaconda3\envs\capstone\Lib\site-packages\streamlit\runtime\caching\cache_utils.py:329, in CachedFunc._handle_cache_miss(self, cache, value_key, func_args, func_kwargs)
#     325 # We acquired the lock before any other thread. Compute the value!
#     326 with self._info.cached_message_replay_ctx.calling_cached_function(
#     327     self._info.func
#     328 ):
# --> 329     computed_value = self._info.func(*func_args, **func_kwargs)
#     331 # We've computed our value, and now we need to write it back to the cache
#     332 # along with any "replay messages" that were generated during value computation.
#     333 messages = self._info.cached_message_replay_ctx._most_recent_messages
#
# Cell In[2], line 12, in load_model()
#      10 @st.cache_resource
#      11 def load_model():
# ---> 12     model = joblib.load('emotion_classifier.joblib')
#      13     model.device = torch.device('cpu')
#      14     if hasattr(model, 'model'):
#
# File ~\anaconda3\envs\capstone\Lib\site-packages\joblib\numpy_pickle.py:749, in load(filename, mmap_mode, ensure_native_byte_order)
#     744                 return load_compatibility(fobj)
#     746             # A memory-mapped array has to be mapped with the endianness
#     747             # it has been written with. Other arrays are coerced to the
#     748             # native endianness of the host system.
# --> 749             obj = _unpickle(
#     750                 fobj,
#     751                 ensure_native_byte_order=ensure_native_byte_order,
#     752                 filename=filename,
#     753                 mmap_mode=validated_mmap_mode,
#     754             )
#     756 return obj
#
# File ~\anaconda3\envs\capstone\Lib\site-packages\joblib\numpy_pickle.py:626, in _unpickle(fobj, ensure_native_byte_order, filename, mmap_mode)
#     624 obj = None
#     625 try:
# --> 626     obj = unpickler.load()
#     627     if unpickler.compat_mode:
#     628         warnings.warn(
#     629             "The file '%s' has been generated with a "
#     630             "joblib version less than 0.10. "
#    (...)    633             stacklevel=3,
#     634         )
#
# File ~\anaconda3\envs\capstone\Lib\pickle.py:1213, in _Unpickler.load(self)
#    1211             raise EOFError
#    1212         assert isinstance(key, bytes_types)
# -> 1213         dispatch[key[0]](self)
#    1214 except _Stop as stopinst:
#    1215     return stopinst.value
#
# File ~\anaconda3\envs\capstone\Lib\pickle.py:1538, in _Unpickler.load_stack_global(self)
#    1536 if type(name) is not str or type(module) is not str:
#    1537     raise UnpicklingError("STACK_GLOBAL requires str")
# -> 1538 self.append(self.find_class(module, name))
#
# File ~\anaconda3\envs\capstone\Lib\pickle.py:1582, in _Unpickler.find_class(self, module, name)
#    1580 __import__(module, level=0)
#    1581 if self.proto >= 4:
# -> 1582     return _getattribute(sys.modules[module], name)[0]
#    1583 else:
#    1584     return getattr(sys.modules[module], name)
#
# File ~\anaconda3\envs\capstone\Lib\pickle.py:331, in _getattribute(obj, name)
#     329         obj = getattr(obj, subpath)
#     330     except AttributeError:
# --> 331         raise AttributeError("Can't get attribute {!r} on {!r}"
#     332                              .format(name, obj)) from None
#     333 return obj, parent
#
# AttributeError: Can't get attribute 'EmotionClassifierSKLearn' on <module '__main__'>
